# %%
import time
print('-=' * 20)
print('TESTE DE BURNOUT'.center(40))
print('-=' * 20)

print("""
Digite o número correspondente a sua resposta:

[1] Nunca
[2] Raramente
[3] Às vezes
[4] Todo tempo
[5] Com muita frequência

""")
pontuacao = 0
for c in range(1, 16):
  if c == 1:
    nota1 = int(input('1 - Você se sente deprimido (a) como se sua energia física e emocional estivesse exaurida? '))
    os.system('cls')
    if nota1 < 1 or nota1 > 5:
      print('Resposta inválida')
      nota1 = 0
      while nota1 < 1 or nota1 > 5:
        nota1 = int(input('1 - Você se sente deprimido (a) como se sua energia física e emocional estivesse exaurida? '))


  if c == 2:
    nota2 = int(input('2 - Você acha que está propenso (a) a pensar negativamente sobre seu emprego? '))
    os.system('cls')
    if nota2 < 1 or nota2 > 5:
      print('Resposta inválida')
      nota2 = 0
      while nota2 < 1 or nota2 > 5:
        nota2 = int(input('2 - Você acha que está propenso (a) a pensar negativamente sobre seu emprego? '))


  if c == 3:
    nota3 = int(input('3 – Você se considera mais frio (a) e/ou menos sensível com as outras pessoas do que possivelmente merecem? '))
    os.system('cls')
    if nota3 < 1 or nota3 > 5:
      print('Resposta inválida')
      nota3 = 0
      while nota3 < 1 or nota3 > 5:
        nota3 = int(input('3 – Você se considera mais frio (a) e/ou menos sensível com as outras pessoas do que possivelmente merecem? '))

  if c == 4:
    nota4 = int(input('4 – Você fica irritado (a) facilmente com os pequenos problemas ou com seus colegas de trabalho e sua equipe? '))
    if nota4 < 1 or nota4 > 5:
      print('Resposta inválida')
      nota4 = 0
      while nota4 < 1 or nota4 > 5:
        nota4 = int(input('4 – Você fica irritado (a) facilmente com os pequenos problemas ou com seus colegas de trabalho e sua equipe?'))

  if c == 5:
    nota5 = int(input('5 – Você se sente incompreendido (a) ou desconsiderado (a) pelos seus colegas de trabalho? '))
    if nota5 < 1 or nota5 > 5:
      print('Resposta inválida')
      nota5 = 0
      while nota5 < 1 or nota5 > 5:
        nota5 = int(input('5 – Você se sente incompreendido (a) ou desconsiderado (a) pelos seus colegas de trabalho? '))

  if c == 6:
    nota6 = int(input('6 – Você sente que não há nada para conversar? '))
    if nota6 < 1 or nota6 > 5:
      print('Resposta inválida')
      nota6 = 0
      while nota6 < 1 or nota6 > 5:
        nota6 = int(input('6 – Você sente que não há nada para conversar? '))

  if c == 7:
    nota7 = int(input('7 – Você acha que está realizando menos do que deveria? '))
    if nota7 < 1 or nota7 > 5:
      print('Resposta inválida')
      nota7 = 0
      while nota7 < 1 or nota7 > 5:
        nota7 = int(input('7 – Você acha que está realizando menos do que deveria? '))

  if c == 8:
    nota8 = int(input('8 – Você se sente em um nível incômodo em relação à pressão para obter êxito? '))
    if nota8 < 1 or nota8 > 5:
      print('Resposta inválida')
      nota8 = 0
      while nota8 < 1 or nota8 > 5:
        nota8 = int(input('8 – Você se sente em um nível incômodo em relação à pressão para obter êxito? '))

  if c == 9:
    nota9 = int(input('9 – Você sente que não está conseguindo o que quer fora do seu emprego? '))
    if nota9 < 1 or nota9 > 5:
      print('Resposta inválida')
      nota9 = 0
      while nota9 < 1 or nota9 > 5:
        nota9 = int(input('9 – Você sente que não está conseguindo o que quer fora do seu emprego? '))

  if c == 10:
    nota10 = int(input('10 – Você sente que está na empresa ou profissão errada? '))
    if nota10 < 1 or nota10 > 5:
      print('Resposta inválida')
      nota10 = 0
      while nota10 < 1 or nota10 > 5:
        nota10 = int(input('10 – Você sente que está na empresa ou profissão errada? '))

  if c == 11:
    nota11 = int(input('11 – Você está ficando frustrado (a) com partes do seu trabalho? '))
    if nota11 < 1 or nota11 > 5:
      print('Resposta inválida')
      nota11 = 0
      while nota11 < 1 or nota11 > 5:
        nota11 = int(input('11 – Você está ficando frustrado (a) com partes do seu trabalho? '))

  if c == 12:
    nota12 = int(input('12 –  Você sente que a burocracia e a política organizacional frustram sua habilidade de realizar um bom trabalho? '))
    if nota12 < 1 or nota12 > 5:
      print('Resposta inválida')
      nota12 = 0
      while nota12 < 1 or nota12 > 5:
        nota12 = int(input('12 –  Você sente que a burocracia e a política organizacional frustram sua habilidade de realizar um bom trabalho? '))

  if c == 13:
    nota13 = int(input('13 – Você sente que há mais trabalho do que você tem habilidade de realizar na prática? '))
    if nota13 < 1 or nota13 > 5:
      print('Resposta inválida')
      nota13 = 0
      while nota13 < 1 or nota13 > 5:
        nota13 = int(input('13 – Você sente que há mais trabalho do que você tem habilidade de realizar na prática? '))

  if c == 14:
    nota14 = int(input('14 – Você acha que não tem tempo para realizar muitas coisas que são importantes e fazer um trabalho com qualidade? '))
    if nota14 < 1 or nota14 > 5:
      print('Resposta inválida')
      nota14 = 0
      while nota14 < 1 or nota14 > 5:
        nota14 = int(input('14 – Você acha que não tem tempo para realizar muitas coisas que são importantes e fazer um trabalho com qualidade? '))

  if c == 15:
    nota15 = int(input('15 – Você acha que não tem tempo para planejar tanto quanto gostaria? '))
    if nota15 < 1 or nota15 > 5:
      print('Resposta inválida')
      nota15 = 0
      while nota15 < 1 or nota15 > 5:
        nota15 = int(input('15 – Você acha que não tem tempo para planejar tanto quanto gostaria? '))

    pontuacao = nota1 + nota2 + nota3 + nota4 + nota5 + nota6 + nota7 + nota8 + nota9 + nota10 + nota11 + nota12 + nota13 + nota14 + nota15

time.sleep(2)
print(f'SUA PONTUAÇÃO FINAL É:  {pontuacao}')
time.sleep(3)
print('aguarde o resultado...')
time.sleep(3)
if pontuacao >= 15 and pontuacao <= 18:
  print('Nenhum sinal de burnout.')
elif pontuacao > 18 and pontuacao <=32:
  print('Pequeno sinal de burnout, a menos que alguns itens (pontuação) estejam particularmente altos.')
elif pontuacao > 32 and pontuacao <= 49:
  print('Cuidado, você corre o risco de burnout, principalmente se muitos ítens estiverem altos.')
elif pontuacao > 49 and pontuacao <= 59:
  print('Você corre um grande risco de burnout. Faça algo a respeito, urgentemente.')
else:
  print('Você está com enorme risco de burnout. Faça algo a respeito urgentemente.')
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#             TESTE DE BURNOUT
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
#
# Digite o número correspondente a sua resposta:
#
# [1] Nunca
# [2] Raramente
# [3] Às vezes
# [4] Todo tempo
# [5] Com muita frequência
#
#
# 1 - Você se sente deprimido (a) como se sua energia física e emocional estivesse exaurida? 1
# 2 - Você acha que está propenso (a) a pensar negativamente sobre seu emprego? 1
# 3 – Você se considera mais frio (a) e/ou menos sensível com as outras pessoas do que possivelmente merecem? 1
# 4 – Você fica irritado (a) facilmente com os pequenos problemas ou com seus colegas de trabalho e sua equipe? 1
# 5 – Você se sente incompreendido (a) ou desconsiderado (a) pelos seus colegas de trabalho? 1
# 6 – Você sente que não há nada para conversar? 1
# 7 – Você acha que está realizando menos do que deveria? 1
# 8 – Você se sente em um nível incômodo em relação à pressão para obter êxito? 1
# ...
